# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import csv, os

from tc_utils import *

# %%
# removed copper as the data range was mentioned as something else and was thus givinig
# copper, fibreglass epoxy, glassfabric-polyester, polystyrene, pvc have multiple thermal conductivities
websites = ['https://trc.nist.gov/cryogenics/materials/1100%20Aluminum/1100%20Aluminum_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/3003F%20Aluminum/3003FAluminum_rev.htm', 
            'https://trc.nist.gov/cryogenics/materials/5083%20Aluminum/5083Aluminum_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/6061%20Aluminum/6061_T6Aluminum_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/6063_T5%20Alulminum/6063-T5Aluminum_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Balsa/Balsa_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Beechwood_Phenolic/beechwood_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Beryllium%20Copper/BerylliumCopper_rev.htm', 
            'https://trc.nist.gov/cryogenics/materials/Brass/Brass_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/G-10%20CR%20Fiberglass%20Epoxy/G10CRFiberglassEpoxy_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Glass%20Fabric%20-%20Polyester/GlassFabric_Polyester_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Iconel%20718/Inconel718_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Invar(Fe-36Ni)/Invar_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Kevlar49/kevlarfiber.htm',
            'https://trc.nist.gov/cryogenics/materials/Kevlar49/kevlarcomposite.htm',
            'https://trc.nist.gov/cryogenics/materials/Lead/Lead_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Molybdenum/Molybdenum_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/NickelSteel/NickelSteel_Fe2.25Ni)_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/NickelSteel/NickelSteel_Fe3.25Ni)_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/NickelSteel/NickelSteel_Fe5.0Ni)_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/NickelSteel/NickelSteel_Fe9.0Ni)_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Platinum/Platinum_rev.htm', 
            'https://trc.nist.gov/cryogenics/materials/Polyamide%20(Nylon)/PolyamideNylon_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/PET/PET_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Polyimide%20Kapton/PolyimideKapton_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Polystyrene/polystyrenerev.html',
            'https://trc.nist.gov/cryogenics/materials/Polyurethane/polyurethanerev.html',
            'https://trc.nist.gov/cryogenics/materials/PVC/PVCrev.htm', 
            'https://trc.nist.gov/cryogenics/materials/304Stainless/304Stainless_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/304LStainless/304LStainless_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/310%20Stainless/310Stainless_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/316Stainless/316Stainless_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Teflon/Teflon_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Ti6Al4V/Ti6Al4V_rev.htm',
            'https://trc.nist.gov/cryogenics/materials/Titanium/Titanium.htm']

# %%
# url
#url = 'https://trc.nist.gov/cryogenics/materials/Balsa/Balsa_rev.htm'
#send an http get request to the url
for i in websites:
    response = requests.get(i)
    soup = BeautifulSoup(response.content,'html.parser')
    results = soup.find(id = 'content') 
    s = results.find('h1')
    # print(s.text)
    tds = []
    b = []
    c = []
    d = []
    y = []
    x = []
    divs = soup.findAll('table', {'class':'properties'})
    for div in divs:
        rows = div.findAll('tr')
        for row in rows:
            tds.append(row.text)

    for i in tds:
        w = i.find('curve fit')
        if w!=-1:
            r = tds.index(i)
            x.append(r)
        else:
            pass

    j = x[0]

    for i in range(1,j+1):
        a = str.split(tds[i], sep='\n')
        b.append(a[1])
        c.append(a[2])
        d.append(a[3])
        
    tuples = [(key, value) for i, (key, value) in enumerate(zip(b, c))]
    res = dict(tuples)
    #print(res)
    
    key = list(res.keys())
    val = list(res.values())
    t = key.index('data range')
    keys1 = []
    vals1 = []
    for i in range(0,t):
        keys1.append(key[i])
        vals1.append(val[i])
    # print(keys1)
    # print(vals1)
    keys2 = []
    vals2 = []
    for i in range(t,t+2):
        keys2.append(key[i])
        f = str.split(val[i], sep='-')
        h = (f[0],f[1])
        vals2.append(h)
    # print(keys2)
    # print(vals2)
    keys3 = []
    vals3 = []
    for i in range(t+2,len(res)):
        keys3.append(key[i])
        vals3.append(val[i])
    # print(keys3)
    # print(vals3)

    #the equation in the website
    formula = divs = soup.findAll('table', {'class':'equation'})
    for form in formula:
        rs = form.findAll('span', class_='style5')
        for r in rs:
            y.append(r.text)
    #print(y[0], end='\n')
            
    







    material_name = s.text.split(":")[1]

    low_fit = np.array(vals1[1:], dtype=float)
    low_fit_xs = np.array(vals2[0], dtype=float)

    print(material_name, low_fit, low_fit_xs)

    fit_types = ["NIST-1"]

    reference = i


    fit_args = dict_monofit(low_fit, low_fit_xs,  fit_types)
    output_array = format_monofit(fit_args)
    print(output_array)
    if not os.path.exists(f"lib\{material_name}"):
            os.mkdir(f"lib\{material_name}")
    if "NIST"in fit_types[0]:
        output_folder = f"lib\{material_name}\\NIST"
        if not os.path.exists(output_folder):
            os.mkdir(output_folder)
        create_tc_csv(output_array, f"{output_folder}\{material_name}.csv")
    else:
        output_folder = f"lib\{material_name}\OTHERFITS"
        if not os.path.exists(output_folder):
            os.mkdir(output_folder)
        create_tc_csv(output_array, f"{output_folder}\{material_name}.csv")
    with open(f"{output_folder}\\reference.txt", 'w') as file:
            file.write(f"{reference}")
# Out:
#  1100 Aluminum (UNS A91100) [  23.39172  -148.5733    422.1917   -653.6664    607.0402   -346.152
#   118.4276    -22.2781      1.770187] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '2.33917e+01', 'b': '-1.48573e+02', 'c': '4.22192e+02', 'd': '-6.53666e+02', 'e': '6.07040e+02', 'f': '-3.46152e+02', 'g': '1.18428e+02', 'h': '-2.22781e+01', 'i': '1.77019e+00'}]
#  3003F Aluminum (UNS A93003) [  0.63736   -1.1437     7.4624   -12.6905    11.9165    -6.18721
#    1.63939   -0.172667   0.      ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '6.37360e-01', 'b': '-1.14370e+00', 'c': '7.46240e+00', 'd': '-1.26905e+01', 'e': '1.19165e+01', 'f': '-6.18721e+00', 'g': '1.63939e+00', 'h': '-1.72667e-01', 'i': '0.00000e+00'}]
#  5083 Aluminum (UNS A95083) [ -0.90933    5.751    -11.112     13.612     -9.3977     3.6873
#   -0.77295    0.067336   0.      ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-9.09330e-01', 'b': '5.75100e+00', 'c': '-1.11120e+01', 'd': '1.36120e+01', 'e': '-9.39770e+00', 'f': '3.68730e+00', 'g': '-7.72950e-01', 'h': '6.73360e-02', 'i': '0.00000e+00'}]
#  6061-T6 Aluminum (UNS A96061) [ 0.07918  1.0957  -0.07277  0.08084  0.02803 -0.09464  0.04179 -0.00571
#   0.     ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '7.91800e-02', 'b': '1.09570e+00', 'c': '-7.27700e-02', 'd': '8.08400e-02', 'e': '2.80300e-02', 'f': '-9.46400e-02', 'g': '4.17900e-02', 'h': '-5.71000e-03', 'i': '0.00000e+00'}]
#  6063-T5 Aluminum (UNS A96063) [  22.401433  -141.13433    394.95461   -601.15377    547.83202
#  -305.99691    102.38656    -18.810237     1.4576882] [  4. 296.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '296.000', 'a': '2.24014e+01', 'b': '-1.41134e+02', 'c': '3.94955e+02', 'd': '-6.01154e+02', 'e': '5.47832e+02', 'f': '-3.05997e+02', 'g': '1.02387e+02', 'h': '-1.88102e+01', 'i': '1.45769e+00'}]
#  Balsa [  4172.447  -11309.97    12745.09    -7647.584    2577.309    -462.538
#      34.5351      0.          0.    ] [ 88. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '88.000', 'High Temp': '300.000', 'a': '4.17245e+03', 'b': '-1.13100e+04', 'c': '1.27451e+04', 'd': '-7.64758e+03', 'e': '2.57731e+03', 'f': '-4.62538e+02', 'g': '3.45351e+01', 'h': '0.00000e+00', 'i': '0.00000e+00'}]
#  Beechwood-Phenolic [-1375.11     3740.69    -4238.465    2559.333    -868.6067    157.1018
#    -11.82957     0.          0.     ] [ 92. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '92.000', 'High Temp': '300.000', 'a': '-1.37511e+03', 'b': '3.74069e+03', 'c': '-4.23847e+03', 'd': '2.55933e+03', 'e': '-8.68607e+02', 'f': '1.57102e+02', 'g': '-1.18296e+01', 'h': '0.00000e+00', 'i': '0.00000e+00'}]
#  Beryllium Copper [-0.50015  1.9319  -1.6954   0.71218  1.2788  -1.6145   0.68722 -0.10501
#   0.     ] [ 2. 80.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '2.000', 'High Temp': '80.000', 'a': '-5.00150e-01', 'b': '1.93190e+00', 'c': '-1.69540e+00', 'd': '7.12180e-01', 'e': '1.27880e+00', 'f': '-1.61450e+00', 'g': '6.87220e-01', 'h': '-1.05010e-01', 'i': '0.00000e+00'}]
#  Brass (UNS C26000) [ 2.10350e-02 -1.01835e+00  4.54083e+00 -5.03374e+00  3.20536e+00
#  -1.12933e+00  1.74057e-01 -3.81510e-03  0.00000e+00] [  5. 116.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '5.000', 'High Temp': '116.000', 'a': '2.10350e-02', 'b': '-1.01835e+00', 'c': '4.54083e+00', 'd': '-5.03374e+00', 'e': '3.20536e+00', 'f': '-1.12933e+00', 'g': '1.74057e-01', 'h': '-3.81510e-03', 'i': '0.00000e+00'}]
#  G-10 CR (Fiberglass Epoxy) [ -4.1236  13.788  -26.068   26.272  -14.663    4.4954  -0.6905   0.0397
#    0.    ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-4.12360e+00', 'b': '1.37880e+01', 'c': '-2.60680e+01', 'd': '2.62720e+01', 'e': '-1.46630e+01', 'f': '4.49540e+00', 'g': '-6.90500e-01', 'h': '3.97000e-02', 'i': '0.00000e+00'}]
#  Glass Fabric - Polyester [  689.532   -2543.63     3967.067   -3400.366    1731.725    -524.309
#     87.4249     -6.19597     0.     ] [ 38. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '38.000', 'High Temp': '300.000', 'a': '6.89532e+02', 'b': '-2.54363e+03', 'c': '3.96707e+03', 'd': '-3.40037e+03', 'e': '1.73172e+03', 'f': '-5.24309e+02', 'g': '8.74249e+01', 'h': '-6.19597e+00', 'i': '0.00000e+00'}]
#  Inconel 718 (UNS N107718) [ -8.28921  39.447   -83.4353   98.169   -67.2088   26.7082   -5.7205
#    0.51115   0.     ] [  6. 275.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '6.000', 'High Temp': '275.000', 'a': '-8.28921e+00', 'b': '3.94470e+01', 'c': '-8.34353e+01', 'd': '9.81690e+01', 'e': '-6.72088e+01', 'f': '2.67082e+01', 'g': '-5.72050e+00', 'h': '5.11150e-01', 'i': '0.00000e+00'}]
#  Invar (Fe-36Ni) (UNS K93600) [ -2.7064     8.5191   -15.923     18.276    -11.9116     4.40318
#   -0.86018    0.068508   0.      ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-2.70640e+00', 'b': '8.51910e+00', 'c': '-1.59230e+01', 'd': '1.82760e+01', 'e': '-1.19116e+01', 'f': '4.40318e+00', 'g': '-8.60180e-01', 'h': '6.85080e-02', 'i': '0.00000e+00'}]
#  Kevlar 49 (Fiber) [-2.4219    1.986637  1.257441  0.961209 -9.6106    0.777857] [1.00e-01 2.91e+02]
# [{'Fit Type': 'NIST-1', 'Low Temp': '0.100', 'High Temp': '291.000', 'a': '-2.42190e+00', 'b': '1.98664e+00', 'c': '1.25744e+00', 'd': '9.61209e-01', 'e': '-9.61060e+00', 'f': '7.77857e-01'}]
#  Kevlar 49 (Composite) [-2.65      1.986637  1.24851   0.57     -8.        0.777857] [  6. 302.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '6.000', 'High Temp': '302.000', 'a': '-2.65000e+00', 'b': '1.98664e+00', 'c': '1.24851e+00', 'd': '5.70000e-01', 'e': '-8.00000e+00', 'f': '7.77857e-01'}]
#  Lead [  38.963479  -221.40505    597.56622   -900.93831    816.40461
#  -455.08342    152.94025    -28.451163     2.2516244] [  4. 296.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '296.000', 'a': '3.89635e+01', 'b': '-2.21405e+02', 'c': '5.97566e+02', 'd': '-9.00938e+02', 'e': '8.16405e+02', 'f': '-4.55083e+02', 'g': '1.52940e+02', 'h': '-2.84512e+01', 'i': '2.25162e+00'}]
#  Molybdenum [  10.78259  -72.13065  228.57351 -384.50447  381.43825 -228.83783
#    81.26658  -15.69097    1.26814] [  2. 373.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '2.000', 'High Temp': '373.000', 'a': '1.07826e+01', 'b': '-7.21307e+01', 'c': '2.28574e+02', 'd': '-3.84504e+02', 'e': '3.81438e+02', 'f': '-2.28838e+02', 'g': '8.12666e+01', 'h': '-1.56910e+01', 'i': '1.26814e+00'}]
#  Nickel Steel (Fe-2.25 Ni) [ -3.5785   20.804   -55.826    87.812   -83.5016   49.08    -17.4348
#    3.4277   -0.28622] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-3.57850e+00', 'b': '2.08040e+01', 'c': '-5.58260e+01', 'd': '8.78120e+01', 'e': '-8.35016e+01', 'f': '4.90800e+01', 'g': '-1.74348e+01', 'h': '3.42770e+00', 'i': '-2.86220e-01'}]
#  Nickel Steel (Fe-3.25 Ni) (UNS S20103) [  0.89481  -8.1998   22.096   -27.645    19.7524   -8.1113    1.77866
#   -0.16172   0.     ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '8.94810e-01', 'b': '-8.19980e+00', 'c': '2.20960e+01', 'd': '-2.76450e+01', 'e': '1.97524e+01', 'f': '-8.11130e+00', 'g': '1.77866e+00', 'h': '-1.61720e-01', 'i': '0.00000e+00'}]
#  Nickel Steel (Fe-5.0 Ni) (UNS S20153) [-0.57245  -0.33593   3.9379   -5.4589    4.2337   -1.8653    0.43223
#  -0.041207  0.      ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-5.72450e-01', 'b': '-3.35930e-01', 'c': '3.93790e+00', 'd': '-5.45890e+00', 'e': '4.23370e+00', 'f': '-1.86530e+00', 'g': '4.32230e-01', 'h': '-4.12070e-02', 'i': '0.00000e+00'}]
#  Nickel Steel (Fe-9.0 Ni) (UNS S21800) [ -0.0712785  -3.48735    10.6547    -12.9153      8.89066    -3.51482
#    0.743643   -0.0657884   0.       ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-7.12785e-02', 'b': '-3.48735e+00', 'c': '1.06547e+01', 'd': '-1.29153e+01', 'e': '8.89066e+00', 'f': '-3.51482e+00', 'g': '7.43643e-01', 'h': '-6.57884e-02', 'i': '0.00000e+00'}]
#  Platinum [  -7.33450054   80.8550484  -268.441084    481.629105   -503.890454
#   314.812622   -115.699394     23.0957119    -1.93361717] [  3. 298.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '3.000', 'High Temp': '298.000', 'a': '-7.33450e+00', 'b': '8.08550e+01', 'c': '-2.68441e+02', 'd': '4.81629e+02', 'e': '-5.03890e+02', 'f': '3.14813e+02', 'g': '-1.15699e+02', 'h': '2.30957e+01', 'i': '-1.93362e+00'}]
#  Polyamide (Nylon) [-2.6135  2.3239 -4.7586  7.1602 -4.9155  1.6324 -0.2507  0.0131  0.    ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-2.61350e+00', 'b': '2.32390e+00', 'c': '-4.75860e+00', 'd': '7.16020e+00', 'e': '-4.91550e+00', 'f': '1.63240e+00', 'g': '-2.50700e-01', 'h': '1.31000e-02', 'i': '0.00000e+00'}]
#  Polyethylene Terephthalate [ -1.37737   -3.40668   20.5842   -53.1244    73.2476   -57.6546
#   26.1192    -6.3479     0.640331] [ 1. 83.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '1.000', 'High Temp': '83.000', 'a': '-1.37737e+00', 'b': '-3.40668e+00', 'c': '2.05842e+01', 'd': '-5.31244e+01', 'e': '7.32476e+01', 'f': '-5.76546e+01', 'g': '2.61192e+01', 'h': '-6.34790e+00', 'i': '6.40331e-01'}]
#  Polyimide (Kapton) [  5.73101 -39.5199   79.9313  -83.8572   50.9157  -17.9835    3.42413
#   -0.27133   0.     ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '5.73101e+00', 'b': '-3.95199e+01', 'c': '7.99313e+01', 'd': '-8.38572e+01', 'e': '5.09157e+01', 'f': '-1.79835e+01', 'g': '3.42413e+00', 'h': '-2.71330e-01', 'i': '0.00000e+00'}]
#  Polystyrene [-1.557500e+03  3.984700e+03 -3.940245e+03  1.649668e+03  1.280097e+01
#  -2.942616e+02  1.195898e+02 -2.063010e+01  1.360670e+00] [ 90. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '90.000', 'High Temp': '300.000', 'a': '-1.55750e+03', 'b': '3.98470e+03', 'c': '-3.94024e+03', 'd': '1.64967e+03', 'e': '1.28010e+01', 'f': '-2.94262e+02', 'g': '1.19590e+02', 'h': '-2.06301e+01', 'i': '1.36067e+00'}]
#  Polyurethane [ -3218.679    9201.61   -10956.66     6950.102   -2476.94      470.284
#     -37.1669      0.          0.    ] [ 76. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '76.000', 'High Temp': '300.000', 'a': '-3.21868e+03', 'b': '9.20161e+03', 'c': '-1.09567e+04', 'd': '6.95010e+03', 'e': '-2.47694e+03', 'f': '4.70284e+02', 'g': '-3.71669e+01', 'h': '0.00000e+00', 'i': '0.00000e+00'}]
#  PVC (Polyvinyl Chloride) [ 11314.56    -30824.32     34964.24    -21141.43      7187.43
#   -1302.708       98.35252      0.           0.     ] [100. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '100.000', 'High Temp': '300.000', 'a': '1.13146e+04', 'b': '-3.08243e+04', 'c': '3.49642e+04', 'd': '-2.11414e+04', 'e': '7.18743e+03', 'f': '-1.30271e+03', 'g': '9.83525e+01', 'h': '0.00000e+00', 'i': '0.00000e+00'}]
#  304 Stainless (UNS S30400) [-1.4087  1.3982  0.2543 -0.626   0.2334  0.4256 -0.4658  0.165  -0.0199] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-1.40870e+00', 'b': '1.39820e+00', 'c': '2.54300e-01', 'd': '-6.26000e-01', 'e': '2.33400e-01', 'f': '4.25600e-01', 'g': '-4.65800e-01', 'h': '1.65000e-01', 'i': '-1.99000e-02'}]
#  304L Stainless (UNS S30403) [-1.4087  1.3982  0.2543 -0.626   0.2334  0.4256 -0.4658  0.165  -0.0199] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-1.40870e+00', 'b': '1.39820e+00', 'c': '2.54300e-01', 'd': '-6.26000e-01', 'e': '2.33400e-01', 'f': '4.25600e-01', 'g': '-4.65800e-01', 'h': '1.65000e-01', 'i': '-1.99000e-02'}]
#  310 Stainless (UNS S31000) [ -0.81907  -2.1967    9.1059  -13.078    10.853    -5.1269    1.2583
#   -0.12395   0.     ] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-8.19070e-01', 'b': '-2.19670e+00', 'c': '9.10590e+00', 'd': '-1.30780e+01', 'e': '1.08530e+01', 'f': '-5.12690e+00', 'g': '1.25830e+00', 'h': '-1.23950e-01', 'i': '0.00000e+00'}]
#  316 Stainless [-1.4087  1.3982  0.2543 -0.626   0.2334  0.4256 -0.4658  0.165  -0.0199] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '-1.40870e+00', 'b': '1.39820e+00', 'c': '2.54300e-01', 'd': '-6.26000e-01', 'e': '2.33400e-01', 'f': '4.25600e-01', 'g': '-4.65800e-01', 'h': '1.65000e-01', 'i': '-1.99000e-02'}]
#  Teflon [   2.738    -30.677     89.43    -136.99     124.69     -69.556
#    23.32      -4.3135     0.33829] [  4. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '4.000', 'High Temp': '300.000', 'a': '2.73800e+00', 'b': '-3.06770e+01', 'c': '8.94300e+01', 'd': '-1.36990e+02', 'e': '1.24690e+02', 'f': '-6.95560e+01', 'g': '2.33200e+01', 'h': '-4.31350e+00', 'i': '3.38290e-01'}]
#  Ti 6Al 4V (UNS R56400) [ -5107.8774    19240.422    -30789.064     27134.756    -14226.379
#    4438.2154     -763.07767      55.796592      0.      ] [ 23. 300.]
# [{'Fit Type': 'NIST-1', 'Low Temp': '23.000', 'High Temp': '300.000', 'a': '-5.10788e+03', 'b': '1.92404e+04', 'c': '-3.07891e+04', 'd': '2.71348e+04', 'e': '-1.42264e+04', 'f': '4.43822e+03', 'g': '-7.63078e+02', 'h': '5.57966e+01', 'i': '0.00000e+00'}]
#  Titanium 15-3-3-3 [ -2.39879484   8.9707438  -29.19286973  54.87139779 -59.67137228
#   38.89321714 -14.94175848   3.11161609  -0.27045277] [  1.4 300. ]
# [{'Fit Type': 'NIST-1', 'Low Temp': '1.400', 'High Temp': '300.000', 'a': '-2.39879e+00', 'b': '8.97074e+00', 'c': '-2.91929e+01', 'd': '5.48714e+01', 'e': '-5.96714e+01', 'f': '3.88932e+01', 'g': '-1.49418e+01', 'h': '3.11162e+00', 'i': '-2.70453e-01'}]
